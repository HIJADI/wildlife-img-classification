# %% [markdown]
# <a href="https://colab.research.google.com/github/HIJADI/wildlife-img-classification/blob/main/speciesnet_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example speciesnet usage
#
# For automatic object detection and animal classification in camera trap images.

# %% [markdown]
# ## Input images directory and output

# %%
# Example images are under my google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMAGES_DIR =  "/content/drive/MyDrive/SFCT_images"
OUTPUT_JSON = "/content/drive/MyDrive/SFCT_images/speciesnet.json"
IMAGES_DIR_SPECIESNET = "/content/drive/MyDrive/SFCT_images_speciesnet"

# !mkdir -p {IMAGES_DIR_SPECIESNET}
# !rm -f {OUTPUT_JSON}

# %%
# !ls -al {IMAGES_DIR}
# Out:
# total 21500
# -rw------- 1 root root    14597 Nov  7 17:57 speciesnet.json
# -rw------- 1 root root   497614 Nov  6 22:21 STC_0006.JPG
# -rw------- 1 root root   616809 Nov  6 22:21 STC_0010.JPG
# -rw------- 1 root root 14625136 Nov  6 22:39 STC_0107.AVI
# -rw------- 1 root root   663882 Nov  6 22:21 STC_0113.JPG
# -rw------- 1 root root   649547 Nov  6 22:21 STC_0117.JPG
# -rw------- 1 root root   660920 Nov  6 22:21 STC_0181.JPG
# -rw------- 1 root root   784521 Nov  6 22:21 STC_0187.JPG
# -rw------- 1 root root   634942 Nov  6 22:21 STC_0270.JPG
# -rw------- 1 root root   775024 Nov  6 22:21 STC_0312.JPG
# -rw------- 1 root root   670597 Nov  6 22:21 STC_0355.JPG
# -rw------- 1 root root   631210 Nov  6 22:21 STC_0482.JPG
# -rw------- 1 root root   788656 Nov  6 22:21 STC_0489.JPG

# %% [markdown]
# ## Install needed packages

# %%
# speciesnet downloads MegaDetector and classification models
# kaggle:google/speciesnet/pyTorch/v4.0.1a etc
# !pip install --upgrade speciesnet[notebooks]

# %%
# install megadetector-utils for annotated output images with bboxes
# !pip install megadetector-utils

# %%
# !python3 -m speciesnet.scripts.run_model --help
# Out:
# Script to run the SpeciesNet model.
#
# Provides a command-line interface to execute the SpeciesNet model on various inputs. It
# uses flags for specifying input, output, and run options, allowing the user to run the
# model in different modes.
#
# flags:
#
# /usr/local/lib/python3.12/dist-packages/speciesnet/scripts/run_model.py:
#   --admin1_region: First-level administrative division (in ISO 3166-2 format,
#     e.g. 'CA') to enforce on all instances.
#   --batch_size: Batch size for classifier inference.
#     (default: '8')
#     (an integer)
#   --[no]bypass_prompts: Whether to bypass confirmation prompts when expected
#     files aren't supplied, or unexpected files are supplied. --bypass_prompts
#     bypasses prompts, --nobypass_prompts (default) does not.
#     (default: 'false')
#   --classifications_json: Input JSON file with classifications from previous
#     runs.
#   --[no]classifier_only: Run only the classifier component. --classifier_only
#     enables classifier-only mode, --noclassifier_only (default) disables it.
#     (default: 'false')
#   --country: Country (in ISO 3166-1 alpha-3 format, e.g. 'AUS') to enforce on
#     all instances.
#   --detections_json: Input JSON file with detections from previous runs.
#   --[no]detector_only: Run only the detector component. --detector_only enables
#     detector-only mode, --nodetector_only (default) disables it.
#     (default: 'false')
#   --[no]ensemble_only: Run only the ensemble component. --ensemble_only enables
#     ensemble-only mode, --noensemble_only (default) disables it.
#     (default: 'false')
#   --filepaths: List of image filepaths to get predictions for.
#     (a comma separated list)
#   --filepaths_txt: Input TXT file with image filepaths to get predictions for.
#   --folders: List of image folders to get predictions for.
#     (a comma separated list)
#   --folders_txt: Input TXT file with image folders to get predictions for.
#   --[no]geofence: Enable geofencing during ensemble prediction. --geofence
#     (default) enables geofencing, --nogeofence disables it.
#     (default: 'true')
#   --instances_json: Input JSON file with instances to get predictions for.
#   --model: SpeciesNet model to load.
#     (default: 'kaggle:google/speciesnet/pyTorch/v4.0.1a')
#   --predictions_json: Output JSON file for storing computed predictions. If this
#     file exists, only instances that are not already present in the output will
#     be processed.
#   --[no]progress_bars: Whether to show progress bars for the various inference
#     components. --progress_bars (default) enables progress bars,
#     --noprogress_bars disables them.
#     (default: 'true')
#   --run_mode: <multi_thread|multi_process>: Parallelism strategy.
#     (default: 'multi_thread')
#   --target_species_txt: Input TXT file with species of interest to always
#     compute classification scores for.
#
# Try --helpfull to get a list of all flags.

# %% [markdown]
# ## Run the object detection and classification pipeline

# %%
# run the detector + classification pipeline on the images
# !python3 -m speciesnet.scripts.run_model --folders {IMAGES_DIR} --predictions_json {OUTPUT_JSON}  --country USA
cmd = f"python3 -m speciesnet.scripts.run_model --folders {IMAGES_DIR} --predictions_json {OUTPUT_JSON}  --country USA"
# !{cmd}
# Out:
# I1107 22:19:44.701361 139400662003712 classifier.py:109] Loaded SpeciesNetClassifier in 1 second on CPU.
# I1107 22:19:45.825698 139400662003712 detector.py:99] Loaded SpeciesNetDetector in 1.12 seconds on CPU.
# I1107 22:19:46.473814 139400662003712 ensemble.py:71] Loaded SpeciesNetEnsemble in 0.65 seconds.
# Detector preprocess   :   0% 0/11 [00:00<?, ?it/s]
# Detector predict      :   0% 0/11 [00:00<?, ?it/s]
#
# Classifier preprocess :   0% 0/11 [00:00<?, ?it/s]
#
#
# Classifier predict    :   0% 0/2 [00:00<?, ?it/s]
#
#
#
# Detector preprocess   :   9% 1/11 [00:00<00:06,  1.45it/s]
#
#
#
# Detector preprocess   :  18% 2/11 [00:01<00:04,  1.97it/s]
# Detector predict      :   9% 1/11 [00:12<02:08, 12.90s/it]
#
# Classifier preprocess :   9% 1/11 [00:13<02:15, 13.60s/it]
#
#
#
# Detector preprocess   :  27% 3/11 [00:13<00:49,  6.16s/it]
# Detector predict      :  18% 2/11 [00:25<01:52, 12.51s/it]
#
# Classifier preprocess :  18% 2/11 [00:25<01:52, 12.51s/it]
#
#
#
# Detector preprocess   :  36% 4/11 [00:25<00:58,  8.35s/it]
# Detector predict      :  27% 3/11 [00:38<01:41, 12.72s/it]
#
# Classifier preprocess :  27% 3/11 [00:38<01:41, 12.73s/it]
#
#
#
# Detector preprocess   :  45% 5/11 [00:38<01:00, 10.01s/it]
# Detector predict      :  36% 4/11 [00:50<01:28, 12.59s/it]
#
# Classifier preprocess :  36% 4/11 [00:50<01:28, 12.59s/it]
#
#
#
# Detector preprocess   :  55% 6/11 [00:51<00:54, 10.84s/it]
# Detector predict      :  45% 5/11 [01:03<01:15, 12.58s/it]
#
# Classifier preprocess :  45% 5/11 [01:03<01:15, 12.57s/it]
#
#
#
# Detector preprocess   :  64% 7/11 [01:03<00:45, 11.38s/it]
# Detector predict      :  55% 6/11 [01:14<01:01, 12.33s/it]
#
# Classifier preprocess :  55% 6/11 [01:15<01:01, 12.33s/it]
#
#
#
# Detector preprocess   :  73% 8/11 [01:15<00:34, 11.53s/it]
# Detector predict      :  64% 7/11 [01:26<00:48, 12.01s/it]
#
# Classifier preprocess :  64% 7/11 [01:26<00:48, 12.04s/it]
#
#
#
# Detector preprocess   :  82% 9/11 [01:26<00:23, 11.53s/it]
# Detector predict      :  73% 8/11 [01:36<00:34, 11.57s/it]
#
# Classifier preprocess :  73% 8/11 [01:37<00:34, 11.56s/it]
#
#
#
# Detector preprocess   :  91% 10/11 [01:37<00:11, 11.25s/it]
#
#
# Classifier predict    :  50% 1/2 [01:58<01:58, 118.07s/it]
# Detector predict      :  82% 9/11 [01:58<00:29, 14.62s/it]
#
# Classifier preprocess :  82% 9/11 [01:58<00:29, 14.62s/it]
#
#
#
# Detector preprocess   : 100% 11/11 [01:58<00:00, 14.29s/it]
# Detector predict      :  91% 10/11 [02:09<00:13, 13.48s/it]
#
# Classifier preprocess :  91% 10/11 [02:09<00:13, 13.53s/it]
#
#
#
# Geolocation           : 100% 11/11 [02:09<00:00, 13.41s/it]
# Detector predict      : 100% 11/11 [02:20<00:00, 12.72s/it]
#
# Classifier preprocess : 100% 11/11 [02:20<00:00, 12.68s/it]
#
#
# Detector preprocess   : 100% 11/11 [02:24<00:00, 13.18s/it]
# Detector predict      : 100% 11/11 [02:24<00:00, 13.18s/it]
# Classifier preprocess : 100% 11/11 [02:24<00:00, 13.18s/it]
# Classifier predict    : 100% 2/2 [02:24<00:00, 72.49s/it]
# Geolocation           : 100% 11/11 [02:24<00:00, 13.18s/it]
# I1107 22:22:11.465951 139400662003712 utils.py:501] Saving predictions to `/content/drive/MyDrive/SFCT_images/speciesnet.tmp.12b48c0e-ed3b-4b00-a61e-f78d48447609.json`.
# I1107 22:22:11.476876 139400662003712 utils.py:503] Moving `/content/drive/MyDrive/SFCT_images/speciesnet.tmp.12b48c0e-ed3b-4b00-a61e-f78d48447609.json` to `/content/drive/MyDrive/SFCT_images/speciesnet.json`.

# %% [markdown]
# ## Generate annotated output images

# %%
# generate annotated output images
cmd = f"python -m megadetector.visualization.visualize_detector_output  {OUTPUT_JSON} {IMAGES_DIR_SPECIESNET}"
# !mkdir -p {PREVIEW_DIR}
# !{cmd}
# Out:
# This appears to be a SpeciesNet output file, converting to MD format
# Detector output file contains 11 entries.
# Rendering detections above a confidence threshold of 0.15
# 100% 11/11 [00:04<00:00,  2.27it/s]
# Skipped 0 failed images (of 11)
# Skipped 0 missing images (of 11)
# Skipped 0 below-threshold images (of 11)
# Rendered detection results to /content/drive/MyDrive/SFCT_images_speciesnet

# %% [markdown]
# ## Load json classification results

# %%
import pandas as pd
import json

# %%
# read its json predictions and make a pandas dataframe for it
with open(OUTPUT_JOSN, 'r') as f:
  data = json.load(f)
num_images = len(data['predictions'])
print(f"Images classified: {num_images}")
# Out:
# Images classified: 11

# %%
# put predictions in a dataframe
df = pd.json_normalize(data['predictions'])
df
# Out:
#                                            filepath country  \
# 0   /content/drive/MyDrive/SFCT_images/STC_0006.JPG     USA
# 1   /content/drive/MyDrive/SFCT_images/STC_0010.JPG     USA
# 2   /content/drive/MyDrive/SFCT_images/STC_0113.JPG     USA
# 3   /content/drive/MyDrive/SFCT_images/STC_0117.JPG     USA
# 4   /content/drive/MyDrive/SFCT_images/STC_0181.JPG     USA
# 5   /content/drive/MyDrive/SFCT_images/STC_0187.JPG     USA
# 6   /content/drive/MyDrive/SFCT_images/STC_0270.JPG     USA
# 7   /content/drive/MyDrive/SFCT_images/STC_0312.JPG     USA
# 8   /content/drive/MyDrive/SFCT_images/STC_0355.JPG     USA
# 9   /content/drive/MyDrive/SFCT_images/STC_0482.JPG     USA
# 10  /content/drive/MyDrive/SFCT_images/STC_0489.JPG     USA
#
#                                            detections  \
# 0   [{'category': '1', 'label': 'animal', 'conf': ...
# 1   [{'category': '1', 'label': 'animal', 'conf': ...
# 2   [{'category': '1', 'label': 'animal', 'conf': ...
# 3   [{'category': '1', 'label': 'animal', 'conf': ...
# 4   [{'category': '1', 'label': 'animal', 'conf': ...
# 5   [{'category': '1', 'label': 'animal', 'conf': ...
# 6   [{'category': '1', 'label': 'animal', 'conf': ...
# 7   [{'category': '1', 'label': 'animal', 'conf': ...
# 8   [{'category': '1', 'label': 'animal', 'conf': ...
# 9   [{'category': '1', 'label': 'animal', 'conf': ...
# 10  [{'category': '1', 'label': 'animal', 'conf': ...
#
#                                            prediction  prediction_score  \
# 0   aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia;...            0.9947
# 1   b1352069-a39c-4a84-a949-60044271c0c1;aves;;;;;...            0.8680
# 2   aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia;...            0.9830
# 3    1f689929-883d-4dae-958c-3d57ab5b6c16;;;;;;animal            0.9022
# 4   f2efdae9-efb8-48fb-8a91-eccf79ab4ffb;no cv res...            0.8358
# 5   aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia;...            0.9851
# 6   e237b8d3-997f-4f3b-8736-8c3958f8182c;aves;pass...            0.7282
# 7   aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia;...            0.9783
# 8   eeeb5d26-2a47-4d01-a3de-10b33ec0aee4;mammalia;...            0.7417
# 9   febff896-db40-4ac8-bcfe-5bb99a600950;mammalia;...            0.9930
# 10  febff896-db40-4ac8-bcfe-5bb99a600950;mammalia;...            0.9780
#
#              prediction_source model_version  \
# 0                   classifier        4.0.1a
# 1                   classifier        4.0.1a
# 2                   classifier        4.0.1a
# 3                     detector        4.0.1a
# 4                   classifier        4.0.1a
# 5                   classifier        4.0.1a
# 6                   classifier        4.0.1a
# 7                   classifier        4.0.1a
# 8   classifier+rollup_to_order        4.0.1a
# 9                   classifier        4.0.1a
# 10                  classifier        4.0.1a
#
#                               classifications.classes  \
# 0   [aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia...
# 1   [b1352069-a39c-4a84-a949-60044271c0c1;aves;;;;...
# 2   [aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia...
# 3   [ffe603fc-4920-4302-96d0-65f708bd5b2d;mammalia...
# 4   [f1856211-cfb7-4a5b-9158-c0f72fd09ee6;;;;;;bla...
# 5   [aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia...
# 6   [e237b8d3-997f-4f3b-8736-8c3958f8182c;aves;pas...
# 7   [aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia...
# 8   [aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia...
# 9   [febff896-db40-4ac8-bcfe-5bb99a600950;mammalia...
# 10  [febff896-db40-4ac8-bcfe-5bb99a600950;mammalia...
#
#                       classifications.scores
# 0   [0.9947, 0.0012, 0.0007, 0.0004, 0.0004]
# 1     [0.868, 0.029, 0.0125, 0.0094, 0.0062]
# 2    [0.983, 0.0029, 0.0025, 0.0022, 0.0012]
# 3   [0.4193, 0.1051, 0.0418, 0.0342, 0.0232]
# 4   [0.8358, 0.0811, 0.0097, 0.0066, 0.0046]
# 5   [0.9851, 0.0063, 0.0027, 0.0008, 0.0008]
# 6   [0.7282, 0.0698, 0.0464, 0.0369, 0.0244]
# 7   [0.9783, 0.0052, 0.0031, 0.0017, 0.0013]
# 8   [0.5408, 0.1196, 0.0355, 0.0229, 0.0229]
# 9      [0.993, 0.002, 0.001, 0.0008, 0.0007]
# 10   [0.978, 0.0111, 0.0042, 0.0019, 0.0011]

# %%
df['prediction'][0]
# Out:
# 'aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia;carnivora;canidae;canis;latrans;coyote'

# %%
df['classifications.classes'][0]
# Out:
# ['aaf3b049-36e6-46dd-9a07-8a580e9618b7;mammalia;carnivora;canidae;canis;latrans;coyote',
#  'b1352069-a39c-4a84-a949-60044271c0c1;aves;;;;;bird',
#  'ba76d46e-25de-45e2-90a8-bd279b650f7c;mammalia;carnivora;felidae;lynx;rufus;bobcat',
#  '9805e578-061a-49c0-8abc-ea135381c162;aves;passeriformes;corvidae;corvus;corax;common raven',
#  '15abc3f7-7155-450e-a590-1730ee9a1adb;mammalia;carnivora;canidae;canis;aureus;golden jackal']
